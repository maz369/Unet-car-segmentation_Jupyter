# %%
# import libraries

import os
import cv2
import time
import h5py
import math
import queue
import pickle
import random
import threading
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as KTF
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from sklearn import model_selection, preprocessing, metrics
from sklearn.model_selection import train_test_split
from tensorflow.python.client import device_lib
from keras.losses import binary_crossentropy
from keras.models import Model, load_model
from sklearn.utils import shuffle
from keras.regularizers import l2
from scipy import misc, ndimage
from keras.optimizers import *
from keras import backend as K
from keras.layers import *

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# get name of available GPU devices. If you do not have any GPU, replace tensorflow-gpu with tensorflow to let
# the network use your CPU
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# create csv file for the images and masks

if not os.path.exists('image.csv'):
    base_dir = os.path.join(os.getcwd(),'data')

    # generate csv file for images
    image_folder = base_dir + '\\images\\'
    images_in_folder = sorted(os.listdir(image_folder))

    # constructing data frame and saving csv file
    df = pd.DataFrame()
    df['images'] = [image_folder + str(x) for x in images_in_folder]
    df.to_csv('image.csv', header=None)

    # generate csv file for masks
    mask_folder = base_dir + '\\masks\\'
    masks_in_folder = sorted(os.listdir(mask_folder))

    # constructing data frame and saving csv file
    df = pd.DataFrame()
    df['masks'] = [mask_folder + str(x) for x in masks_in_folder]
    df.to_csv('mask.csv', header=None)

# %%
# import list of image and mask paths from the csv file
# NOTE: you can directly load image from the folder without any need for creating and loading from
#       a CSV file. However, its recommended to have a cvs file becasue it makes it easier to make
#       changes in the data set or loading only part of the dataset

import csv
def get_path_csv(folder, csv_file):
    with open(os.path.join(folder, csv_file), 'r') as f:
        reader = csv.reader(f)
        meta_data = list(reader)
        path_list = [item[1] for item in meta_data]
    return path_list
try:
    csvFile.close()
except:
    print("Could not close CSV file")
    
folder = os.getcwd()
img_path = get_path_csv(folder, 'image.csv')
mask_path = get_path_csv(folder, 'mask.csv')
# Out:
# Could not close CSV file

# %%
# load images; im_height & im_width can be selected. Larger resolution provides better result but 
# makes the training slow
# images are normalized to have intensity values between 0 and 1
# In this example images are loaded as gray scale (shape=(x,y)). Their dimensions are expanded by adding value of 1 to the 
# 3rd dimension (shape=(x,y,1)).

im_height = 64
im_width = 64

imgs = []
for i in img_path:
    img_array = cv2.imread(i, 0)/255
    new_array = cv2.resize(img_array, (im_height, im_width))
    new_array = np.expand_dims(new_array, axis=-1)
    imgs.append(new_array)
    
masks = []
for i in mask_path:
    mask_array = cv2.imread(i, 0)/255
    new_mask = cv2.resize(mask_array, (im_height, im_width))
    new_mask = np.expand_dims(new_mask, axis=-1)
    masks.append(new_mask)
    
    
# convert to numpy array
imgs_np = np.array(imgs, dtype=np.float32)
masks_np = np.array(masks, dtype=np.float32)

# %%
# show 7 randomly selected images and masks

rand_idx = random.choices(range(0,len(imgs)), k=7)

for i in rand_idx:
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    ax[0].imshow(imgs[i].squeeze(), cmap='gray')
    ax[1].imshow(masks[i].squeeze(), cmap='gray' )

# %%
# split dataset for test and train

X_train, X_valid, y_train, y_valid = train_test_split(imgs_np, masks_np, test_size=0.2, random_state=1)

# %%
# define 2D convolutional layer with relu activation function

def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
# define 2D Unet network

def get_unet(input_img, n_filters=2, dropout=0.5, batchnorm=True):
    
    # contracting path (encoder)
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path (decoder)
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(1, (1,1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
# select input size and model parameters. We used keras built-in binary crossentropy loss

input_img = Input((im_height, im_width, 1), name='img')
model = get_unet(input_img, n_filters=2, dropout=0.05, batchnorm=True)
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 2)    20          img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 2)    8           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 2)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 2)    38          activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 2)    8           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 2)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 2)    0           activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 2)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 4)    76          dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 4)    16          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 4)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 4)    148         activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 4)    16          conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 4)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 4)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 4)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 8)    296         dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 8)    32          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 8)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 8)    584         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 8)    32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 8)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 8)      0           activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 8)      0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 16)     1168        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 16)     64          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 8, 8, 16)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 16)     2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 16)     64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 8, 8, 16)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 16)     0           activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 16)     0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 32)     4640        dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 4, 4, 32)     128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 32)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 32)     9248        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 4, 4, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 32)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 8, 8, 16)     4624        activation_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 32)     0           conv2d_transpose_1[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 32)     0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 16)     4624        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 16)     64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 16)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 16)     2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 16)     64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 16)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 8)    1160        activation_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 16)   0           conv2d_transpose_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 16)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 8)    1160        dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 8)    32          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 8)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 16, 16, 8)    584         activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 8)    32          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 8)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 4)    292         activation_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 8)    0           conv2d_transpose_3[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 8)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 4)    292         dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 4)    16          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 4)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 4)    148         activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 4)    16          conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 4)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 2)    74          activation_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 4)    0           conv2d_transpose_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 64, 64, 4)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 2)    74          dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 2)    8           conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 2)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 2)    38          activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 2)    8           conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 2)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 1)    3           activation_18[0][0]
# ==================================================================================================
# Total params: 34,667
# Trainable params: 34,299
# Non-trainable params: 368
# __________________________________________________________________________________________________

# %%
# define call back to save model and perform early stopping if loss does not imporove after 10 training epoch

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
callbacks = [EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=10, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-car_segmentation.h5', verbose=1, save_best_only=True, save_weights_only=True)]

# %%
# train the model, select batch size and number of epoches

results = model.fit(X_train, y_train, batch_size=5, epochs=100, verbose=2, callbacks=None,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 115 samples, validate on 29 samples
# Epoch 1/100
#  - 7s - loss: 0.8825 - accuracy: 0.4834 - val_loss: 0.6880 - val_accuracy: 0.7385
# Epoch 2/100
#  - 1s - loss: 0.7747 - accuracy: 0.6240 - val_loss: 0.6815 - val_accuracy: 0.7687
# Epoch 3/100
#  - 1s - loss: 0.6691 - accuracy: 0.7620 - val_loss: 0.6736 - val_accuracy: 0.7986
# Epoch 4/100
#  - 1s - loss: 0.6100 - accuracy: 0.8596 - val_loss: 0.6524 - val_accuracy: 0.8363
# Epoch 5/100
#  - 1s - loss: 0.5838 - accuracy: 0.9054 - val_loss: 0.6419 - val_accuracy: 0.8394
# Epoch 6/100
#  - 1s - loss: 0.5652 - accuracy: 0.9292 - val_loss: 0.6349 - val_accuracy: 0.8384
# Epoch 7/100
#  - 1s - loss: 0.5513 - accuracy: 0.9407 - val_loss: 0.6462 - val_accuracy: 0.8003
# Epoch 8/100
#  - 1s - loss: 0.5393 - accuracy: 0.9467 - val_loss: 0.6424 - val_accuracy: 0.7942
# Epoch 9/100
#  - 1s - loss: 0.5296 - accuracy: 0.9501 - val_loss: 0.6069 - val_accuracy: 0.8578
# Epoch 10/100
#  - 1s - loss: 0.5201 - accuracy: 0.9523 - val_loss: 0.5926 - val_accuracy: 0.8675
# Epoch 11/100
#  - 1s - loss: 0.5107 - accuracy: 0.9547 - val_loss: 0.5473 - val_accuracy: 0.9143
# Epoch 12/100
#  - 1s - loss: 0.5019 - accuracy: 0.9567 - val_loss: 0.5201 - val_accuracy: 0.9331
# Epoch 13/100
#  - 1s - loss: 0.4925 - accuracy: 0.9582 - val_loss: 0.5094 - val_accuracy: 0.9388
# Epoch 14/100
#  - 1s - loss: 0.4851 - accuracy: 0.9588 - val_loss: 0.4983 - val_accuracy: 0.9428
# Epoch 15/100
#  - 1s - loss: 0.4765 - accuracy: 0.9605 - val_loss: 0.4881 - val_accuracy: 0.9461
# Epoch 16/100
#  - 1s - loss: 0.4690 - accuracy: 0.9608 - val_loss: 0.4721 - val_accuracy: 0.9582
# Epoch 17/100
#  - 1s - loss: 0.4611 - accuracy: 0.9625 - val_loss: 0.4600 - val_accuracy: 0.9615
# Epoch 18/100
#  - 1s - loss: 0.4537 - accuracy: 0.9625 - val_loss: 0.4530 - val_accuracy: 0.9634
# Epoch 19/100
#  - 1s - loss: 0.4468 - accuracy: 0.9626 - val_loss: 0.4500 - val_accuracy: 0.9611
# Epoch 20/100
#  - 1s - loss: 0.4396 - accuracy: 0.9636 - val_loss: 0.4385 - val_accuracy: 0.9650
# Epoch 21/100
#  - 1s - loss: 0.4322 - accuracy: 0.9647 - val_loss: 0.4303 - val_accuracy: 0.9660
# Epoch 22/100
#  - 1s - loss: 0.4245 - accuracy: 0.9657 - val_loss: 0.4229 - val_accuracy: 0.9668
# Epoch 23/100
#  - 1s - loss: 0.4186 - accuracy: 0.9656 - val_loss: 0.4141 - val_accuracy: 0.9693
# Epoch 24/100
#  - 1s - loss: 0.4123 - accuracy: 0.9656 - val_loss: 0.4099 - val_accuracy: 0.9670
# Epoch 25/100
#  - 1s - loss: 0.4045 - accuracy: 0.9674 - val_loss: 0.4051 - val_accuracy: 0.9658
# Epoch 26/100
#  - 1s - loss: 0.3987 - accuracy: 0.9671 - val_loss: 0.3958 - val_accuracy: 0.9691
# Epoch 27/100
#  - 1s - loss: 0.3919 - accuracy: 0.9681 - val_loss: 0.3952 - val_accuracy: 0.9658
# Epoch 28/100
#  - 1s - loss: 0.3858 - accuracy: 0.9685 - val_loss: 0.3876 - val_accuracy: 0.9681
# Epoch 29/100
#  - 1s - loss: 0.3793 - accuracy: 0.9689 - val_loss: 0.3788 - val_accuracy: 0.9701
# Epoch 30/100
#  - 1s - loss: 0.3736 - accuracy: 0.9696 - val_loss: 0.3736 - val_accuracy: 0.9701
# Epoch 31/100
#  - 1s - loss: 0.3681 - accuracy: 0.9697 - val_loss: 0.3696 - val_accuracy: 0.9690
# Epoch 32/100
#  - 1s - loss: 0.3633 - accuracy: 0.9692 - val_loss: 0.3635 - val_accuracy: 0.9699
# Epoch 33/100
#  - 1s - loss: 0.3569 - accuracy: 0.9702 - val_loss: 0.3588 - val_accuracy: 0.9690
# Epoch 34/100
#  - 1s - loss: 0.3513 - accuracy: 0.9710 - val_loss: 0.3546 - val_accuracy: 0.9694
# Epoch 35/100
#  - 1s - loss: 0.3463 - accuracy: 0.9708 - val_loss: 0.3479 - val_accuracy: 0.9708
# Epoch 36/100
#  - 1s - loss: 0.3406 - accuracy: 0.9712 - val_loss: 0.3379 - val_accuracy: 0.9728
# Epoch 37/100
#  - 1s - loss: 0.3356 - accuracy: 0.9716 - val_loss: 0.3349 - val_accuracy: 0.9717
# Epoch 38/100
#  - 1s - loss: 0.3309 - accuracy: 0.9716 - val_loss: 0.3302 - val_accuracy: 0.9729
# Epoch 39/100
#  - 1s - loss: 0.3258 - accuracy: 0.9720 - val_loss: 0.3276 - val_accuracy: 0.9716
# Epoch 40/100
#  - 1s - loss: 0.3210 - accuracy: 0.9725 - val_loss: 0.3219 - val_accuracy: 0.9721
# Epoch 41/100
#  - 1s - loss: 0.3163 - accuracy: 0.9724 - val_loss: 0.3196 - val_accuracy: 0.9713
# Epoch 42/100
#  - 1s - loss: 0.3118 - accuracy: 0.9724 - val_loss: 0.3126 - val_accuracy: 0.9733
# Epoch 43/100
#  - 1s - loss: 0.3071 - accuracy: 0.9732 - val_loss: 0.3071 - val_accuracy: 0.9733
# Epoch 44/100
#  - 1s - loss: 0.3021 - accuracy: 0.9735 - val_loss: 0.3052 - val_accuracy: 0.9717
# Epoch 45/100
#  - 1s - loss: 0.2983 - accuracy: 0.9734 - val_loss: 0.3015 - val_accuracy: 0.9719
# Epoch 46/100
#  - 1s - loss: 0.2940 - accuracy: 0.9737 - val_loss: 0.2937 - val_accuracy: 0.9747
# Epoch 47/100
#  - 1s - loss: 0.2886 - accuracy: 0.9745 - val_loss: 0.2924 - val_accuracy: 0.9725
# Epoch 48/100
#  - 1s - loss: 0.2846 - accuracy: 0.9748 - val_loss: 0.2866 - val_accuracy: 0.9739
# Epoch 49/100
#  - 1s - loss: 0.2813 - accuracy: 0.9745 - val_loss: 0.2866 - val_accuracy: 0.9717
# Epoch 50/100
#  - 1s - loss: 0.2774 - accuracy: 0.9744 - val_loss: 0.2782 - val_accuracy: 0.9748
# Epoch 51/100
#  - 1s - loss: 0.2719 - accuracy: 0.9754 - val_loss: 0.2722 - val_accuracy: 0.9756
# Epoch 52/100
#  - 1s - loss: 0.2677 - accuracy: 0.9757 - val_loss: 0.2712 - val_accuracy: 0.9739
# Epoch 53/100
#  - 1s - loss: 0.2638 - accuracy: 0.9755 - val_loss: 0.2680 - val_accuracy: 0.9737
# Epoch 54/100
#  - 1s - loss: 0.2602 - accuracy: 0.9758 - val_loss: 0.2633 - val_accuracy: 0.9747
# Epoch 55/100
#  - 1s - loss: 0.2569 - accuracy: 0.9756 - val_loss: 0.2610 - val_accuracy: 0.9735
# Epoch 56/100
#  - 1s - loss: 0.2540 - accuracy: 0.9753 - val_loss: 0.2552 - val_accuracy: 0.9752
# Epoch 57/100
#  - 1s - loss: 0.2492 - accuracy: 0.9764 - val_loss: 0.2524 - val_accuracy: 0.9749
# Epoch 58/100
#  - 1s - loss: 0.2471 - accuracy: 0.9757 - val_loss: 0.2512 - val_accuracy: 0.9736
# Epoch 59/100
#  - 1s - loss: 0.2433 - accuracy: 0.9761 - val_loss: 0.2472 - val_accuracy: 0.9745
# Epoch 60/100
#  - 1s - loss: 0.2395 - accuracy: 0.9766 - val_loss: 0.2458 - val_accuracy: 0.9732
# Epoch 61/100
#  - 1s - loss: 0.2366 - accuracy: 0.9767 - val_loss: 0.2406 - val_accuracy: 0.9746
# Epoch 62/100
#  - 1s - loss: 0.2339 - accuracy: 0.9761 - val_loss: 0.2406 - val_accuracy: 0.9729
# Epoch 63/100
#  - 1s - loss: 0.2305 - accuracy: 0.9767 - val_loss: 0.2340 - val_accuracy: 0.9753
# Epoch 64/100
#  - 1s - loss: 0.2267 - accuracy: 0.9773 - val_loss: 0.2295 - val_accuracy: 0.9761
# Epoch 65/100
#  - 1s - loss: 0.2240 - accuracy: 0.9773 - val_loss: 0.2275 - val_accuracy: 0.9756
# Epoch 66/100
#  - 1s - loss: 0.2215 - accuracy: 0.9769 - val_loss: 0.2232 - val_accuracy: 0.9763
# Epoch 67/100
#  - 1s - loss: 0.2177 - accuracy: 0.9776 - val_loss: 0.2216 - val_accuracy: 0.9762
# Epoch 68/100
#  - 1s - loss: 0.2155 - accuracy: 0.9775 - val_loss: 0.2199 - val_accuracy: 0.9759
# Epoch 69/100
#  - 1s - loss: 0.2125 - accuracy: 0.9776 - val_loss: 0.2172 - val_accuracy: 0.9755
# Epoch 70/100
#  - 1s - loss: 0.2096 - accuracy: 0.9780 - val_loss: 0.2129 - val_accuracy: 0.9769
# Epoch 71/100
#  - 1s - loss: 0.2079 - accuracy: 0.9777 - val_loss: 0.2132 - val_accuracy: 0.9750
# Epoch 72/100
#  - 1s - loss: 0.2045 - accuracy: 0.9782 - val_loss: 0.2094 - val_accuracy: 0.9762
# Epoch 73/100
#  - 1s - loss: 0.2017 - accuracy: 0.9782 - val_loss: 0.2069 - val_accuracy: 0.9758
# Epoch 74/100
#  - 1s - loss: 0.1991 - accuracy: 0.9785 - val_loss: 0.2052 - val_accuracy: 0.9756
# Epoch 75/100
#  - 1s - loss: 0.1964 - accuracy: 0.9786 - val_loss: 0.2008 - val_accuracy: 0.9770
# Epoch 76/100
#  - 1s - loss: 0.1948 - accuracy: 0.9783 - val_loss: 0.1975 - val_accuracy: 0.9771
# Epoch 77/100
#  - 1s - loss: 0.1925 - accuracy: 0.9781 - val_loss: 0.1958 - val_accuracy: 0.9772
# Epoch 78/100
#  - 1s - loss: 0.1893 - accuracy: 0.9786 - val_loss: 0.1921 - val_accuracy: 0.9776
# Epoch 79/100
#  - 1s - loss: 0.1868 - accuracy: 0.9788 - val_loss: 0.1901 - val_accuracy: 0.9779
# Epoch 80/100
#  - 1s - loss: 0.1850 - accuracy: 0.9787 - val_loss: 0.1913 - val_accuracy: 0.9759
# Epoch 81/100
#  - 1s - loss: 0.1826 - accuracy: 0.9789 - val_loss: 0.1897 - val_accuracy: 0.9759
# Epoch 82/100
#  - 1s - loss: 0.1805 - accuracy: 0.9788 - val_loss: 0.1846 - val_accuracy: 0.9776
# Epoch 83/100
#  - 1s - loss: 0.1779 - accuracy: 0.9792 - val_loss: 0.1822 - val_accuracy: 0.9778
# Epoch 84/100
#  - 1s - loss: 0.1758 - accuracy: 0.9793 - val_loss: 0.1802 - val_accuracy: 0.9776
# Epoch 85/100
#  - 1s - loss: 0.1737 - accuracy: 0.9793 - val_loss: 0.1783 - val_accuracy: 0.9778
# Epoch 86/100
#  - 1s - loss: 0.1711 - accuracy: 0.9797 - val_loss: 0.1766 - val_accuracy: 0.9774
# Epoch 87/100
#  - 1s - loss: 0.1697 - accuracy: 0.9794 - val_loss: 0.1756 - val_accuracy: 0.9768
# Epoch 88/100
#  - 1s - loss: 0.1683 - accuracy: 0.9792 - val_loss: 0.1747 - val_accuracy: 0.9767
# Epoch 89/100
#  - 1s - loss: 0.1669 - accuracy: 0.9791 - val_loss: 0.1714 - val_accuracy: 0.9774
# Epoch 90/100
#  - 1s - loss: 0.1647 - accuracy: 0.9789 - val_loss: 0.1686 - val_accuracy: 0.9777
# Epoch 91/100
#  - 1s - loss: 0.1624 - accuracy: 0.9793 - val_loss: 0.1693 - val_accuracy: 0.9764
# Epoch 92/100
#  - 1s - loss: 0.1609 - accuracy: 0.9792 - val_loss: 0.1666 - val_accuracy: 0.9771
# Epoch 93/100
#  - 1s - loss: 0.1575 - accuracy: 0.9801 - val_loss: 0.1648 - val_accuracy: 0.9769
# Epoch 94/100
#  - 1s - loss: 0.1575 - accuracy: 0.9794 - val_loss: 0.1630 - val_accuracy: 0.9771
# Epoch 95/100
#  - 1s - loss: 0.1556 - accuracy: 0.9795 - val_loss: 0.1604 - val_accuracy: 0.9778
# Epoch 96/100
#  - 1s - loss: 0.1538 - accuracy: 0.9795 - val_loss: 0.1601 - val_accuracy: 0.9771
# Epoch 97/100
#  - 1s - loss: 0.1520 - accuracy: 0.9796 - val_loss: 0.1589 - val_accuracy: 0.9766
# Epoch 98/100
#  - 1s - loss: 0.1495 - accuracy: 0.9799 - val_loss: 0.1545 - val_accuracy: 0.9786
# Epoch 99/100
#  - 1s - loss: 0.1475 - accuracy: 0.9802 - val_loss: 0.1545 - val_accuracy: 0.9773
# Epoch 100/100
#  - 1s - loss: 0.1468 - accuracy: 0.9797 - val_loss: 0.1509 - val_accuracy: 0.9788

# %%
# plot training and validation loss, then highlight best model

plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
# make prediction image based on the trained network

preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_valid, verbose=1)
# Out:
# 115/115 [==============================] - 1s 10ms/step
# 29/29 [==============================] - 0s 11ms/step

# %%
# model evaluation

loss, acc =  model.evaluate(X_valid, y_valid, batch_size=30, verbose=1)
display('Evaluation loss is equal to: {0:.2f}'.format(loss))
display('Evaluation accuracy is equal to: {0:.2f}'.format(acc))
# Out:
# 29/29 [==============================] - 0s 451us/step
# 'Evaluation loss is equal to: 0.15'
# 'Evaluation accuracy is equal to: 0.98'

# %%
# show examples from validation dataset

rand_idx = random.choices(range(0,len(X_valid)), k=7)

for idx in rand_idx:
    fig, ax = plt.subplots(1, 3, figsize=(20, 10))
    ax[0].imshow(X_valid[idx].squeeze(), cmap='gray')
    ax[0].title.set_text('Original image')
    ax[1].imshow(y_valid[idx].squeeze(), cmap='gray')
    ax[1].title.set_text('Ground-truth mask')
    ax[2].imshow(preds_val[idx].squeeze(), cmap='gray')
    ax[2].title.set_text('Predicted mask')
